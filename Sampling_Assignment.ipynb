# %% [markdown]
# <a href="https://colab.research.google.com/github/Jasmeet-Kaur16/Sampling/blob/master/Sampling_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import math
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB

# %%
data=pd.read_csv("/content/Creditcard_data.csv")
data
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 0       0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1       0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ..    ...       ...       ...       ...       ...       ...       ...
# 767   575 -0.572263  0.731748  1.541254  0.150506  1.108974  0.372152
# 768   579 -1.296845 -0.511605  2.404726 -0.310762 -0.319551 -0.542842
# 769   579  1.214170  0.210481  0.484651  0.479768 -0.261955 -0.527039
# 770   580  1.267030 -0.071114  0.037680  0.512683  0.242392  0.705212
# 771   581  1.153758  0.132273  0.382969  1.405063 -0.224287 -0.197295
#
#            V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,roc_auc_score

y_train=data['Class']
x_train=data.drop(columns='Class')
X_train, X_test, Y_train, Y_test = train_test_split(x_train, y_train, test_size = 0.2, random_state =43 )

xgb_model = XGBClassifier().fit(x_train, y_train)

xgb_y_predict = xgb_model.predict(x_train)

xgb_score = roc_auc_score(xgb_y_predict, y_train)

print('Accuracy score is:', xgb_score)
# Out:
# Accuracy score is: 1.0

# %%
class_count_0, class_count_1 = data['Class'].value_counts()

class_0 = data[data['Class'] == 0]
class_1 = data[data['Class'] == 1]

print('class 0:', class_0.shape)
print('class 1:', class_1.shape)
# Out:
# class 0: (763, 31)
# class 1: (9, 31)

# %%
x=data.drop(['Class'],axis=1)
y=data['Class']
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=2)

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
smote=SMOTE(sampling_strategy='minority')
x_smote, y_smote = smote.fit_resample(x, y)

print('Original dataset shape', Counter(y_train))
print('Resample dataset shape', Counter(y_smote))
# Out:
# Original dataset shape Counter({0: 535, 1: 5})
# Resample dataset shape Counter({0: 763, 1: 763})

# %%
df=pd.DataFrame(x_smote)
df['Class']=y_smote
df
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 0        0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2        1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3        1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4        2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...    ...       ...       ...       ...       ...       ...       ...
# 1521   286 -0.310052  0.492504  0.945595  0.140892  0.877876 -0.189855
# 1522   479  0.985595  0.407548  0.340235  0.558353 -0.086468 -0.764395
# 1523   124  0.438835 -0.385258  0.709157  0.611358  0.626595  0.077240
# 1524   411 -2.369431  1.552334 -1.398784  3.864204 -0.374975 -1.398251
# 1525   473 -2.141754 -0.480704  0.620201  2.434707  1.110119 -0.321197
#
#             V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
s=[]

# %%
#Random sampling
random_sample_size=math.ceil((1.96**2 * 0.5 * (1 - 0.5)) / (0.05**2))
s1=df.sample(random_sample_size)
s1['Class'].value_counts()
s.append(s1)

# %%
#Stratified sampling
stratified_sample_size=math.ceil((1.96**2 * 0.5 * (1 - 0.5)) / ((0.05/0.7)**2))
s2=df.groupby('Class',group_keys=False).apply(lambda x: x.sample(stratified_sample_size))
s2['Class'].value_counts()
s.append(s2)

# %%
#Systematic sampling
systematic_sample_size=math.ceil((1.96**2 * 0.5 * (1 - 0.5)) / (0.05**2))
k=math.ceil(len(df)/systematic_sample_size)
s3=df.iloc[::k]
s3['Class'].value_counts()
s.append(s3)

# %%
#Bootstrap sampling
bootstrap_sample_size=math.ceil((1.96**2 * 0.5 * (1 - 0.5)) / (0.05**2))
s4=df.sample(bootstrap_sample_size,replace=True)
s4['Class'].value_counts()
s.append(s4)

# %%
#cluster sampling
cluster_sample_size=math.ceil((1.96**2 * 0.5 * (1 - 0.5)) / ((0.05/1.5)**2))
K=math.ceil(len(df)/cluster_sample_size)
clusters=2
data=None
for k in range(K):
    sample_k = df.sample(cluster_sample_size)
    sample_k["cluster"] = np.repeat(k,len(sample_k))
    df_new = df.drop(index = sample_k.index)
    data = pd.concat([data,sample_k],axis = 0)

random_chosen_clusters = np.random.randint(0,K,size = clusters)
s5 = data[data.cluster.isin(random_chosen_clusters)]
s5.drop(['cluster'], axis=1, inplace=True)
s5['Class'].value_counts()
s.append(s5)
# Out:
# <ipython-input-171-846bd209a8b5>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s5.drop(['cluster'], axis=1, inplace=True)

# %%
mat=pd.DataFrame(columns=['Simple-Random','Stratified','Systematic','Bootstrap','Cluster'], index=['Random Forest','SVM','Logistic Regression','KNN','Naive Bayes'])

# %%
for i in range(0,5):
  j=0
  inp=s[i].drop(['Class'],axis=1)
  out=s[i]['Class']
  inp_train, inp_test, out_train, out_test = train_test_split(inp ,out ,test_size=0.25, shuffle=True)

  # Applying Random Forest Classifier
  rfc = RandomForestClassifier()
  rfc.fit(inp_train, out_train)
  y_pred = rfc.predict(inp_test)
  acc = accuracy_score(out_test, y_pred)
  mat.iloc[j,i]=acc*100


  # Applying SVM
  svm = SVC(kernel='rbf')
  svm.fit(inp_train, out_train)
  y_pred=svm.predict(inp_test)
  acc = accuracy_score(out_test, y_pred)
  mat.iloc[j+1,i]=acc*100


  # Applying Logistic Regression
  lr = LogisticRegression(max_iter=2000)
  lr.fit(inp_train, out_train)
  y_pred = lr.predict(inp_test)
  acc = accuracy_score(out_test, y_pred)
  mat.iloc[j+2,i]=acc*100


  # Applying knn
  scaler=StandardScaler()
  inp_train_scaled=scaler.fit_transform(inp_train)
  inp_test_scaled=scaler.fit_transform(inp_test)

  knn=KNeighborsClassifier()
  knn.fit(inp_train_scaled,out_train)

  out_pred=knn.predict(inp_test)
  acc=accuracy_score(out_test,out_pred)
  mat.iloc[j+3,i]=acc*100

  # Applying Naive bayes
  model = GaussianNB()
  model.fit(x_train,y_train)
  predicted= model.predict(inp_test)
  acc = accuracy_score(out_test, y_pred)
  mat.iloc[j+4,i]=acc*100
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
mat
# Out:
#                     Simple-Random Stratified Systematic  Bootstrap    Cluster
# Random Forest           97.938144      100.0     96.875      100.0      100.0
# SVM                     62.886598  65.263158  57.291667  67.010309  65.898618
# Logistic Regression     91.752577  87.368421  91.666667  89.690722  89.861751
# KNN                     56.701031  63.157895  69.791667  68.041237  70.046083
# Naive Bayes             91.752577  87.368421  91.666667  89.690722  89.861751
